# %%
#! pip install transformers
#! pip install vaderSentiment

# %%
import pandas as pd
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
import os
from tqdm.auto import tqdm

# %% [markdown]
# ## 1. SentiWordNet

# %%
from sentiment_analysis_1 import *

# %%
articles = load_titles()
print(len(articles), "articles found")
# Out:
# 4604 articles found

# %%
content = load_html(articles)
set(content[k][0] for k in content.keys())
# Out:
# {'\n'}

# %% [markdown]
# ## Load sentiment data

# %%
sentiment_lexicon_path = "../sentiwordnet/SentiWordNet_3.0.0.txt"
df = pd.read_csv(sentiment_lexicon_path, sep="\t", skiprows=25, skipfooter=1, engine="python")
df
# Out:
#        # POS       ID  PosScore  NegScore          SynsetTerms  \
# 0          a     1740     0.125     0.000               able#1
# 1          a     2098     0.000     0.750             unable#1
# 2          a     2312     0.000     0.000   dorsal#2 abaxial#1
# 3          a     2527     0.000     0.000  ventral#2 adaxial#1
# 4          a     2730     0.000     0.000         acroscopic#1
# ...      ...      ...       ...       ...                  ...
# 117654     v  2771756     0.000     0.000  run_dry#1 dry_out#2
# 117655     v  2771888     0.000     0.125             fog_up#1
# 117656     v  2771997     0.000     0.000        coal#1 char#1
# 117657     v  2772202     0.125     0.250               haze#1
# 117658     v  2772310     0.125     0.000         deflagrate#1
#
#                                                     Gloss
# 0       (usually followed by `to') having the necessar...
# 1       (usually followed by `to') not having the nece...
# 2       facing away from the axis of an organ or organ...
# 3       nearest to or facing toward the axis of an org...
# 4                   facing or on the side toward the apex
# ...                                                   ...
# 117654  become empty of water; "The river runs dry in ...
# 117655              get foggy; "The windshield fogged up"
# 117656  burn to charcoal; "Without a drenching rain, t...
# 117657                       become hazy, dull, or cloudy
# 117658  cause to burn rapidly and with great intensity...
#
# [117659 rows x 6 columns]

# %%
def parse_synset_terms(row):
    words = row.split()
    words = [word.split('#')[0] for word in words]
    return words

df['SynsetTerms'] = df['SynsetTerms'].apply(parse_synset_terms)
df = df.explode('SynsetTerms').reset_index(drop=True)
df
# Out:
#        # POS       ID  PosScore  NegScore SynsetTerms  \
# 0          a     1740     0.125     0.000        able
# 1          a     2098     0.000     0.750      unable
# 2          a     2312     0.000     0.000      dorsal
# 3          a     2312     0.000     0.000     abaxial
# 4          a     2527     0.000     0.000     ventral
# ...      ...      ...       ...       ...         ...
# 206936     v  2771888     0.000     0.125      fog_up
# 206937     v  2771997     0.000     0.000        coal
# 206938     v  2771997     0.000     0.000        char
# 206939     v  2772202     0.125     0.250        haze
# 206940     v  2772310     0.125     0.000  deflagrate
#
#                                                     Gloss
# 0       (usually followed by `to') having the necessar...
# 1       (usually followed by `to') not having the nece...
# 2       facing away from the axis of an organ or organ...
# 3       facing away from the axis of an organ or organ...
# 4       nearest to or facing toward the axis of an org...
# ...                                                   ...
# 206936              get foggy; "The windshield fogged up"
# 206937  burn to charcoal; "Without a drenching rain, t...
# 206938  burn to charcoal; "Without a drenching rain, t...
# 206939                       become hazy, dull, or cloudy
# 206940  cause to burn rapidly and with great intensity...
#
# [206941 rows x 6 columns]

# %%
positiveness = dict(zip(df.SynsetTerms, round(df.PosScore - df.NegScore,5)))     # positiveness/negativeness score on [-1,1]
extremeness = dict(zip(df.SynsetTerms, (df.PosScore + df.NegScore)/2))  # extremeness score on [0,1]

# %% [markdown]
# ## Load validation data

# %%
validation = pd.read_csv("../validation.txt", sep="\t", header=None, names=["article", "sentiment"])
validation = validation.set_index("article")
validation.head()
# Out:
#                                sentiment
# article
# 1755_Lisbon_earthquake                -1
# 1896_Summer_Olympics                   1
# 1997_Pacific_hurricane_season         -1
# Actinium                               0
# Barracuda                             -1

# %% [markdown]
# ## Model
# Since there is no training we can go straight to validation data

# %%
def model(articles_content, lexicon):
    """
    Infer the sentiment prediction for articles on their content, according to lexicon of sentiments
    Args:
        articles_content: dict(), dictionary of (article-title: article-content) pairs
        lexicon: dict(), dictionary of (word: sentiment) pairs, with sentiment a sentiment score
    Returns:
        dict(), dictionary of (article-title: average-score) pairs
    """
    article_scores = {}

    for title, content in articles_content.items():
        words = content.split()
        word_scores = [lexicon[word] for word in words if word in lexicon]
        average_score = sum(word_scores) / len(word_scores) if len(word_scores) > 0 else None
        article_scores[title] = average_score

    return article_scores

# %%
validation_content = dict(zip(list(validation.index), [None]*len(validation)))
for k in validation_content.keys():
    validation_content[k] = content[k]

# %%
scores = model(validation_content, positiveness)

# %%
validation["prediction"] = scores

# %%
validation.head(), validation.describe()
# Out:
# (                               sentiment  prediction
#  article
#  1755_Lisbon_earthquake                -1   -0.050156
#  1896_Summer_Olympics                   1   -0.006281
#  1997_Pacific_hurricane_season         -1   -0.037893
#  Actinium                               0   -0.005826
#  Barracuda                             -1   -0.002747,
#         sentiment  prediction
#  count  35.000000   35.000000
#  mean   -0.085714   -0.007911
#  std     0.853072    0.016548
#  min    -1.000000   -0.051758
#  25%    -1.000000   -0.011520
#  50%     0.000000   -0.005826
#  75%     1.000000    0.001189
#  max     1.000000    0.017951)

# %% [markdown]
# ## Score predictions by the sign

# %%
print(sum((validation["sentiment"] * validation["prediction"]) > 0), "/", len(validation))
# Out:
# 15 / 35

# %% [markdown]
# ## Prediction corrected by validation average (but better if we correct with training average)

# %%
print(sum((validation["sentiment"] * (validation["prediction"] + validation["prediction"].mean())) > 0), "/", len(validation))
# Out:
# 16 / 35

# %%
validation.to_csv('sentiment_analysis_1.csv', index=False)

# %% [markdown]
# # 2.

# %%
file_names = ['1755_Lisbon_earthquake','1896_Summer_Olympics','1997_Pacific_hurricane_season','Actinium','Barracuda','Basketball','Bath_School_disaster','Chicago','Chocolate','Diamond','Dice','Drinking_water','Duchenne_muscular_dystrophy','Geography_of_Ireland','Giraffe','Gunpowder','Osama_bin_Laden','Palm_oil','Peace','Pellagra','Phishing','Plant','Plato','Pneumonia','Poison_gas_in_World_War_I','Politics','Pollution','Red_Kite','Rice','Rio_de_Janeiro','Romeo_and_Juliet','Rugby_World_Cup','Rwandan_Genocide','Santa_Claus','Scooby-Doo']
len(file_names)
# Out:
# 35

# %% [markdown]
# ### MODEL DESCRIPTION
# Pattern is a multipurpose library that is capable of handling NLP operations, data mining, machine learning etc. It also contains sentiment analysis functionality which is suitable for our task.
# The `sentiment` function under `pattern.text.en` module is used to calculate the sentiment of a given text, it takes a sentence as input which can also be a string, Synset, word or document, and returns a (polarity, subjectivity)-tuple with polarity between -1.0 and +1.0 and subjectivity between 0.0 and 1.0. polarity describes the emotional leaning of the text, while subjectivity describes the strength of such emotion.
#
# In our usage the input is a string of the entire article loaded from the Wikispeedia dataset, In this case, it first tokenizes the text into words(punctuation, space and abbreviations are handled at this stage), then it Lowercases each word because sentiment analysis is case insensitive. Next it calculates the sentiment of each word by consulting the predefined sentiment [dictionary](https://github.com/clips/pattern/blob/master/pattern/text/en/en-sentiment.xml)(modifiers and negations are also considered at this time). Finally it returns the average of all the words as the sentiment of the text.
#
# Pattern is a classic and well-known non-commercial library for the sentiment analysis task solution, the module itself lasts over 10 years and has 8.6k stars on github. It provides detailed results (polarity and subjectivity) for many mainstream languages, and its API is fast and easy to use with other NLP preprocessing tools embedded. More details can be found in the [official documentation](https://digiasset.org/html/pattern.html) and [repository](https://digiasset.org/html/pattern.html).

# %% [markdown]
# ### METHOD && RESULTS
# Each selected article is loaded and feeded into the `sentiment` function, the polarity is then printed out. The results are shown below.

# %%
from pattern.text.en import sentiment

for file_name in file_names:
    with open('data/plaintext_articles/'+file_name+'.txt', 'r', encoding='utf-8') as file:
        data = file.read()
        polarity, subjectivity = sentiment(data)
        print(f"{file_name}: {polarity}")
# Out:
# 1755_Lisbon_earthquake: 0.0816923282902664
# 1896_Summer_Olympics: 0.11173071331653418
# 1997_Pacific_hurricane_season: 0.051366249491249474
# Actinium: 0.03542682926829269
# Barracuda: 0.1132213321465658
# Basketball: 0.08600218021995364
# Bath_School_disaster: 0.010679336219336222
# Chicago: 0.10564842500695483
# Chocolate: 0.07674311830989919
# Diamond: 0.12359236785162714
# Dice: -0.0001423413188119043
# Drinking_water: 0.12155415214866433
# Duchenne_muscular_dystrophy: 0.051342562953478464
# Geography_of_Ireland: 0.06101678376268537
# Giraffe: 0.04892030793508625
# Gunpowder: 0.01667841269841271
# Osama_bin_Laden: 0.04482218734525007
# Palm_oil: 0.10377811870669014
# Peace: 0.07109719189365207
# Pellagra: 0.013132859204287773
# Phishing: 0.03130031080031078
# Plant: 0.09383068133068131
# Plato: 0.16051446416831025
# Pneumonia: 0.05341062158293232
# Poison_gas_in_World_War_I: 0.08464027042373903
# Politics: 0.10395405509821987
# Pollution: 0.08715013543960917
# Red_Kite: 0.035212025919573085
# Rice: 0.08478642004761416
# Rio_de_Janeiro: 0.15940676171654442
# Romeo_and_Juliet: 0.08846829977782353
# Rugby_World_Cup: 0.09477842945584883
# Rwandan_Genocide: 0.05457812020169003
# Santa_Claus: 0.08992885441238731
# Scooby-Doo: 0.1352173090752449

# %% [markdown]
# The MSE is compared with the human labeled result(trinary value among -1 0 1) which is around **0.7**

# %% [markdown]
# ### DISCUSSION
# The performance of this model is generally not good compared to other models we tested, the possible reason could be that it uses a fixed sentiment dictionary which may contain bias between different domains. It's observed that the model tends to give a very small value between [0,0.1] despite the articles, a reason could be that Wikipedia articles are designed to be neutral and objective, It generally looks at problems dialectically and rarely produces strong emotions. However, in the range of this project, we care more about the sentiment level of the article (the word itself) rather than the way it is written, the model considers all the words on the page evenly and thus may produce results that are not what we expect.
#
# This is not the optimal model for our task, a ML-based approach is generally more flexible and powerful in this case.

# %% [markdown]
# # 3. Vader

# %% [markdown]
# VADER (Valence Aware Dictionary and sEntiment Reasoner) is a sentiment analysis method attuned expressions from social media. This model classies the text into positive, neutral, and negative parts, then by leveraging lexicon and grammatical rules, from valence scores compute the 'compound score' which is normalized weighted composite score of the sentiment of the text.
#
# Utilizing NLTK, VADER takes into condsideration the text nuances, informal phrases, and even non-English text sentences.

# %%
from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer
from tqdm.auto import tqdm
import os
import pandas as pd

# %% [markdown]
# ## Load articles' titles and content

# %%
titles_path = "Feuille de calcul sans titre - results.csv"
html_dir = "plaintext_articles"

def load_titles(file_path=titles_path):
    """
    Load the titles of Wikispeedia pages

    Input args:
        file_path: path to the text file which contains the list of wikipedia articles
    Output:
        titles: List, list of Wikipedia pages used in Wikispeedia
    """
    titles = pd.read_csv(file_path, header=None)
    titles.columns = ['title']
    return titles

def load_html(titles, dir=html_dir):
    """
    Load the text of Wikispeedia pages

    Input args:
        titles: pandas Dataframe of wikipedia titles for which to retrieve html content
        dir: path to the directory containing the wikipedia articles' html content
    Output:
        content: Dict, dictionary of (title: html content) pairs
    """
    content = []
    for title in titles.title:
        path = os.path.join(dir,title+".txt")
        if os.path.exists(path):
            with open(path, 'r', encoding='utf-8') as file:
                html_content = file.readlines()
                content.append("".join(html_content[1:]))
        else:
            print("WARNING: file", path, "is missing")
    titles['content'] = content
    return titles

# %%
articles = load_titles()
len(articles)
# Out:
# 35

# %%
content = load_html(articles)
content
# Out:
#                             title  \
# 0          1755_Lisbon_earthquake
# 1            1896_Summer_Olympics
# 2   1997_Pacific_hurricane_season
# 3                        Actinium
# 4                       Barracuda
# 5                      Basketball
# 6            Bath_School_disaster
# 7                         Chicago
# 8                       Chocolate
# 9                         Diamond
# 10                           Dice
# 11                 Drinking_water
# 12    Duchenne_muscular_dystrophy
# 13           Geography_of_Ireland
# 14                        Giraffe
# 15                      Gunpowder
# 16                Osama_bin_Laden
# 17                       Palm_oil
# 18                          Peace
# 19                       Pellagra
# 20                       Phishing
# 21                          Plant
# 22                          Plato
# 23                      Pneumonia
# 24      Poison_gas_in_World_War_I
# 25                       Politics
# 26                      Pollution
# 27                       Red_Kite
# 28                           Rice
# 29                 Rio_de_Janeiro
# 30               Romeo_and_Juliet
# 31                Rugby_World_Cup
# 32               Rwandan_Genocide
# 33                    Santa_Claus
# 34                     Scooby-Doo
#
#                                               content
# 0   \n1755 Lisbon earthquake\n\n2007 Schools Wikip...
# 1   \n1896 Summer Olympics\n\n2007 Schools Wikiped...
# 2   \n1997 Pacific hurricane season\n\n2007 School...
# 3   \nActinium\n\n2007 Schools Wikipedia Selection...
# 4   \nBarracuda\n\n2007 Schools Wikipedia Selectio...
# 5   \nBasketball\n\n2007 Schools Wikipedia Selecti...
# 6   \nBath School disaster\n\n2007 Schools Wikiped...
# 7   \nChicago\n\n2007 Schools Wikipedia Selection....
# 8   \nChocolate\n\n2007 Schools Wikipedia Selectio...
# 9   \nDiamond\n\n2007 Schools Wikipedia Selection....
# 10  \nDice\n\n2007 Schools Wikipedia Selection. Re...
# 11  \nDrinking water\n\n2007 Schools Wikipedia Sel...
# 12  \nDuchenne muscular dystrophy\n\n2007 Schools ...
# 13  \nGeography of Ireland\n\n2007 Schools Wikiped...
# 14  \nGiraffe\n\n2007 Schools Wikipedia Selection....
# 15  \nGunpowder\n\n2007 Schools Wikipedia Selectio...
# 16  \nOsama bin Laden\n\n2007 Schools Wikipedia Se...
# 17  \nPalm oil\n\n2007 Schools Wikipedia Selection...
# 18  \nPeace\n\n2007 Schools Wikipedia Selection. R...
# 19  \nPellagra\n\n2007 Schools Wikipedia Selection...
# 20  \nPhishing\n\n2007 Schools Wikipedia Selection...
# 21  \nPlant\n\n2007 Schools Wikipedia Selection. R...
# 22  \nPlato\n\n2007 Schools Wikipedia Selection. R...
# 23  \nPneumonia\n\n2007 Schools Wikipedia Selectio...
# 24  \nPoison gas in World War I\n\n2007 Schools Wi...
# 25  \nPolitics\n\n2007 Schools Wikipedia Selection...
# 26  \nPollution\n\n2007 Schools Wikipedia Selectio...
# 27  \nRed Kite\n\n2007 Schools Wikipedia Selection...
# 28  \nRice\n\n2007 Schools Wikipedia Selection. Re...
# 29  \nRio de Janeiro\n\n2007 Schools Wikipedia Sel...
# 30  \nRomeo and Juliet\n\n2007 Schools Wikipedia S...
# 31  \nRugby World Cup\n\n2007 Schools Wikipedia Se...
# 32  \nRwandan Genocide\n\n2007 Schools Wikipedia S...
# 33  \nSanta Claus\n\n2007 Schools Wikipedia Select...
# 34  \nScooby-Doo\n\n2007 Schools Wikipedia Selecti...

# %% [markdown]
# ## Analysing the compound score

# %%
scores = []
analyzer = SentimentIntensityAnalyzer()
for article_content in tqdm(content.iloc):
    vs = analyzer.polarity_scores(article_content.content)
    scores.append(vs['compound'])
# Out:
# 0it [00:00, ?it/s]

# %%
content['score'] = scores
content
# Out:
#                             title  \
# 0          1755_Lisbon_earthquake
# 1            1896_Summer_Olympics
# 2   1997_Pacific_hurricane_season
# 3                        Actinium
# 4                       Barracuda
# 5                      Basketball
# 6            Bath_School_disaster
# 7                         Chicago
# 8                       Chocolate
# 9                         Diamond
# 10                           Dice
# 11                 Drinking_water
# 12    Duchenne_muscular_dystrophy
# 13           Geography_of_Ireland
# 14                        Giraffe
# 15                      Gunpowder
# 16                Osama_bin_Laden
# 17                       Palm_oil
# 18                          Peace
# 19                       Pellagra
# 20                       Phishing
# 21                          Plant
# 22                          Plato
# 23                      Pneumonia
# 24      Poison_gas_in_World_War_I
# 25                       Politics
# 26                      Pollution
# 27                       Red_Kite
# 28                           Rice
# 29                 Rio_de_Janeiro
# 30               Romeo_and_Juliet
# 31                Rugby_World_Cup
# 32               Rwandan_Genocide
# 33                    Santa_Claus
# 34                     Scooby-Doo
#
#                                               content   score
# 0   \n1755 Lisbon earthquake\n\n2007 Schools Wikip... -0.9970
# 1   \n1896 Summer Olympics\n\n2007 Schools Wikiped...  0.9999
# 2   \n1997 Pacific hurricane season\n\n2007 School... -0.9998
# 3   \nActinium\n\n2007 Schools Wikipedia Selection... -0.8792
# 4   \nBarracuda\n\n2007 Schools Wikipedia Selectio...  0.9944
# 5   \nBasketball\n\n2007 Schools Wikipedia Selecti...  0.9999
# 6   \nBath School disaster\n\n2007 Schools Wikiped... -0.9998
# 7   \nChicago\n\n2007 Schools Wikipedia Selection....  0.9999
# 8   \nChocolate\n\n2007 Schools Wikipedia Selectio...  0.9996
# 9   \nDiamond\n\n2007 Schools Wikipedia Selection....  1.0000
# 10  \nDice\n\n2007 Schools Wikipedia Selection. Re... -0.9998
# 11  \nDrinking water\n\n2007 Schools Wikipedia Sel...  0.9890
# 12  \nDuchenne muscular dystrophy\n\n2007 Schools ... -0.9924
# 13  \nGeography of Ireland\n\n2007 Schools Wikiped...  0.9853
# 14  \nGiraffe\n\n2007 Schools Wikipedia Selection....  0.9933
# 15  \nGunpowder\n\n2007 Schools Wikipedia Selectio... -0.9935
# 16  \nOsama bin Laden\n\n2007 Schools Wikipedia Se... -0.9998
# 17  \nPalm oil\n\n2007 Schools Wikipedia Selection...  0.9991
# 18  \nPeace\n\n2007 Schools Wikipedia Selection. R...  0.9999
# 19  \nPellagra\n\n2007 Schools Wikipedia Selection... -0.5844
# 20  \nPhishing\n\n2007 Schools Wikipedia Selection... -0.9984
# 21  \nPlant\n\n2007 Schools Wikipedia Selection. R...  0.9950
# 22  \nPlato\n\n2007 Schools Wikipedia Selection. R...  0.9998
# 23  \nPneumonia\n\n2007 Schools Wikipedia Selectio... -0.9995
# 24  \nPoison gas in World War I\n\n2007 Schools Wi... -1.0000
# 25  \nPolitics\n\n2007 Schools Wikipedia Selection...  0.9996
# 26  \nPollution\n\n2007 Schools Wikipedia Selectio...  0.9968
# 27  \nRed Kite\n\n2007 Schools Wikipedia Selection... -0.9598
# 28  \nRice\n\n2007 Schools Wikipedia Selection. Re...  0.9997
# 29  \nRio de Janeiro\n\n2007 Schools Wikipedia Sel...  0.9998
# 30  \nRomeo and Juliet\n\n2007 Schools Wikipedia S...  0.9980
# 31  \nRugby World Cup\n\n2007 Schools Wikipedia Se...  0.9977
# 32  \nRwandan Genocide\n\n2007 Schools Wikipedia S... -0.9999
# 33  \nSanta Claus\n\n2007 Schools Wikipedia Select...  0.9525
# 34  \nScooby-Doo\n\n2007 Schools Wikipedia Selecti...  0.9998

# %% [markdown]
# As can be inferred from the prediction, the model is good at correctly splitting the articles into two separate clusters, with a quite impressive squared error of 0.2. However, the obtained scores are quite extreme, making it impractical to infer the intensity of the negative or positive sense of each article. This could be attributed to the prevalence of neutral words, causing smaller differences between negative and positive counterparts.

# %%
content.drop(columns='content').to_csv('results.csv',index=False,header=False)

# %% [markdown]
# # 4. Roberta

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer
import numpy as np
from scipy.special import softmax
import csv
import urllib.request

def preprocess(text):
    new_text = []


    for t in text.split(" "):
        t = '@user' if t.startswith('@') and len(t) > 1 else t
        t = 'http' if t.startswith('http') else t
        new_text.append(t)
    return " ".join(new_text)

def chunk_text(text, max_length):
    words = text.split()
    for i in range(0, len(words), max_length):
        yield ' '.join(words[i:i+max_length])

task = 'sentiment'
MODEL = f"cardiffnlp/twitter-roberta-base-{task}"

tokenizer = AutoTokenizer.from_pretrained(MODEL)
max_length = 512

# download label mapping
labels=[]
mapping_link = f"https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/{task}/mapping.txt"
with urllib.request.urlopen(mapping_link) as f:
    html = f.read().decode('utf-8').split("\n")
    csvreader = csv.reader(html, delimiter='\t')
labels = [row[1] for row in csvreader if len(row) > 1]

model = AutoModelForSequenceClassification.from_pretrained(MODEL)

text = input("Enter the text you want to analyze: ")
chunks = chunk_text(preprocess(text), max_length)


# Assume labels are in the order of [negative, neutral, positive]
# Adjust the scores to be in the range of [-1, 1]
# For simplicity, this assumes three classes. If there are more classes, the mapping will need to be adjusted accordingly.
final_scores = np.zeros(len(labels))
for chunk in chunks:
    encoded_input = tokenizer(chunk, return_tensors='pt', truncation=True, max_length=max_length)
    output = model(**encoded_input)
    scores = softmax(output[0][0].detach().numpy())
    final_scores += scores

# Normalize the final_scores
final_scores /= final_scores.sum()

# Now, map the scores to the range of [-1, 1]
# This mapping assumes the labels are in the correct order.
if len(labels) == 3:  # Check if there are three sentiment categories
    # Mapping: Negative * -1 + Neutral * 0 + Positive * 1
    sentiment_score = final_scores[2] - final_scores[0]  # positive score minus negative score
else:
    raise ValueError("The number of sentiment labels is not equal to 3, and the scoring system needs to be adjusted.")

print(f"{sentiment_score:.2f}")
# Out:
# Enter the text you want to analyze:    #copyright  Drought  2007 Schools Wikipedia Selection. Related subjects: Climate and the Weather     Fields outside Benambra, Victoria suffering from drought conditions    Fields outside Benambra, Victoria suffering from drought conditions     A drought is an extended period of months or years when a region notes    a deficiency in its water supply. Generally, this occurs when a region    receives consistently below average precipitation. However, it can also    be worsened by man. It can have a substantial impact on the ecosystem    and agriculture of the affected region. Although droughts can be    long-lived, even a short, intense drought can cause significant damage    .     Man-made erosion can play a role, as it did in the North American Dust    Bowl in the 1930s, as can general climate change. Many speculate that    global warming will have a substantial impact on agriculture throughout    the world, and especially in developing nations. For most regions,    drought is a normal, recurrent feature of the climate, and having    adequate drought mitigation strategies in place can greatly reduce the    impact. Regardless of the cause, recurring drought can also bring about    desertification. Recurring droughts in the Horn of Africa have created    grave ecological catastrophes, prompting massive food shortages, still    recurring.  Consequences     Periods of drought can have significant environmental, economic and    social consequences. The most common consequences include:      * Death of livestock.      * Reduced crop yields.      * Wildfires, such as Australian bushfires, are more common during        times of drought.      * Shortages of water for industrial users.      * Desertification      * Dust storms      * Malnutrition, dehydration and related diseases.      * Famine due to lack of water for irrigation.      * Social unrest.      * Mass migration, resulting in internal displacement and        international refugees.      * War over natural resources, including water and food.     The effect varies according to vulnerability. For example, subsistence    farmers are more likely to migrate during drought because they do not    have alternative food sources. Areas with populations that depend on    subsistence farming as a major food source are more vulnerable to    drought-triggered famine. Drought is rarely if ever the sole cause of    famine; socio-political factors such as extreme widespread poverty play    a major role. Drought can also reduce water quality, because lower    water flows reduce dilution of pollutants and increase contamination of    remaining water sources.  Stages of drought     Ship stranded by the retreat of the Aral Sea    Ship stranded by the retreat of the Aral Sea     As a drought persists, the conditions surrounding it gradually worsen    and its impact on the local population gradually increases. Droughts go    through three stages before their ultimate cessation :     1. Meteorological drought is brought about when there is a prolonged        period with less than average precipitation. Meteorological drought        usually precedes the other kinds of drought.     2. Agricultural droughts are droughts that affect crop production or        the ecology of the range. This condition can also arise        independently from any change in precipitation levels when soil        conditions and erosion triggered by poorly planned agricultural        endeavors cause a shortfall in water available to the crops.        However, in a traditional drought, it is caused by an extended        period of below average precipitation.     3. Hydrological drought is brought about when the water reserves        available in sources such as aquifers, lakes and reservoirs falls        below the statistical average. Like an agricultural drought, this        can be triggered by more than just a loss of rainfall. For        instance, Kazakhstan was recently awarded a large  ...
# -0.44

# %%
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import numpy as np
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')


# Assuming the file is already extracted and available as 'SentiWordNet.txt'

sentiwordnet_dict = {}
file_path = '/content/SentiWordNet_3.0.0.txt'  # Update with your actual file path

# Read the file and parse the sentiment scores
with open(file_path, 'r') as swndata:
    for line in swndata:
        # Skip comments and blank lines
        if line.startswith('#') or not line.strip():
            continue
        # Split the line by tab and ensure it has 6 elements
        parts = line.strip().split('\t')
        if len(parts) == 6:
            pos, id, pos_score, neg_score, synset_terms, gloss = parts
            if float(pos_score) == 0.0 and float(neg_score) == 0.0:
                continue
            # Some terms have multiple words separated by space, take the first one
            term = synset_terms.split(' ')[0].split('#')[0]  # Get the term without sense number
            if term:  # Check if the term is not empty
                # The dictionary key is the term and the values are the positive and negative scores
                sentiwordnet_dict[term] = {'PosScore': float(pos_score), 'NegScore': float(neg_score)}

# After populating sentiwordnet_dict
print(list(sentiwordnet_dict.items())[:10])  # Print the first 10 entries



# Now you can use sentiwordnet_dict to look up sentiment scores


# Define the preprocess and sentiment analysis functions
def preprocess(text):
    lemmatizer = WordNetLemmatizer()
    stop_words = set(stopwords.words('english'))
    tokens = word_tokenize(text)
    processed_tokens = [lemmatizer.lemmatize(token) for token in tokens if token.lower() not in stop_words and token.isalpha()]
    #print("Processed words:", processed_tokens)  # This line will print the preprocessed words
    return processed_tokens

def analyze_sentiment(words, sentiwordnet):
    positive_score = negative_score = word_count = 0

    for word in words:
        if word in sentiwordnet:
            print(f"Word: {word}, PosScore: {sentiwordnet[word]['PosScore']}, NegScore: {sentiwordnet[word]['NegScore']}")
            positive_score += sentiwordnet[word]['PosScore']
            negative_score += sentiwordnet[word]['NegScore']
            word_count += 1
    # ...

    if word_count == 0:
        return 0  # Neutral if no words found in SentiWordNet

    # Normalize scores
    avg_positive_score = positive_score / word_count
    avg_negative_score = negative_score / word_count
    total_score = avg_positive_score - avg_negative_score

    return np.clip(total_score, -1, 1)


# Input text
text = input("Enter the text for sentiment analysis: ")
preprocessed_text = preprocess(text)

# Analyze sentiment
sentiment_score = analyze_sentiment(preprocessed_text, sentiwordnet_dict)
print(f"Sentiment score: {sentiment_score}")
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [('able', {'PosScore': 0.125, 'NegScore': 0.0}), ('unable', {'PosScore': 0.125, 'NegScore': 0.25}), ('dissilient', {'PosScore': 0.25, 'NegScore': 0.0}), ('parturient', {'PosScore': 0.25, 'NegScore': 0.0}), ('uncut', {'PosScore': 0.375, 'NegScore': 0.25}), ('absolute', {'PosScore': 0.0, 'NegScore': 0.25}), ('direct', {'PosScore': 0.125, 'NegScore': 0.0}), ('unquestioning', {'PosScore': 0.25, 'NegScore': 0.625}), ('infinite', {'PosScore': 0.125, 'NegScore': 0.5}), ('living', {'PosScore': 0.0, 'NegScore': 0.125})]
# Enter the text for sentiment analysis:    #copyright  Drought  2007 Schools Wikipedia Selection. Related subjects: Climate and the Weather     Fields outside Benambra, Victoria suffering from drought conditions    Fields outside Benambra, Victoria suffering from drought conditions     A drought is an extended period of months or years when a region notes    a deficiency in its water supply. Generally, this occurs when a region    receives consistently below average precipitation. However, it can also    be worsened by man. It can have a substantial impact on the ecosystem    and agriculture of the affected region. Although droughts can be    long-lived, even a short, intense drought can cause significant damage    .     Man-made erosion can play a role, as it did in the North American Dust    Bowl in the 1930s, as can general climate change. Many speculate that    global warming will have a substantial impact on agriculture throughout    the world, and especially in developing nations. For most regions,    drought is a normal, recurrent feature of the climate, and having    adequate drought mitigation strategies in place can greatly reduce the    impact. Regardless of the cause, recurring drought can also bring about    desertification. Recurring droughts in the Horn of Africa have created    grave ecological catastrophes, prompting massive food shortages, still    recurring.  Consequences     Periods of drought can have significant environmental, economic and    social consequences. The most common consequences include:      * Death of livestock.      * Reduced crop yields.      * Wildfires, such as Australian bushfires, are more common during        times of drought.      * Shortages of water for industrial users.      * Desertification      * Dust storms      * Malnutrition, dehydration and related diseases.      * Famine due to lack of water for irrigation.      * Social unrest.      * Mass migration, resulting in internal displacement and        international refugees.      * War over natural resources, including water and food.     The effect varies according to vulnerability. For example, subsistence    farmers are more likely to migrate during drought because they do not    have alternative food sources. Areas with populations that depend on    subsistence farming as a major food source are more vulnerable to    drought-triggered famine. Drought is rarely if ever the sole cause of    famine; socio-political factors such as extreme widespread poverty play    a major role. Drought can also reduce water quality, because lower    water flows reduce dilution of pollutants and increase contamination of    remaining water sources.  Stages of drought     Ship stranded by the retreat of the Aral Sea    Ship stranded by the retreat of the Aral Sea     As a drought persists, the conditions surrounding it gradually worsen    and its impact on the local population gradually increases. Droughts go    through three stages before their ultimate cessation :     1. Meteorological drought is brought about when there is a prolonged        period with less than average precipitation. Meteorological drought        usually precedes the other kinds of drought.     2. Agricultural droughts are droughts that affect crop production or        the ecology of the range. This condition can also arise        independently from any change in precipitation levels when soil        conditions and erosion triggered by poorly planned agricultural        endeavors cause a shortfall in water available to the crops.        However, in a traditional drought, it is caused by an extended        period of below average precipitation.     3. Hydrological drought is brought about when the water reserves        available in sources such as aquifers, lakes and reservoirs falls        below the statistical average. Like an agricultural drought, this        can be triggered by more than just a loss of rainfall. For        instance, Kazakhstan was recently awarded a lar ...
# Word: subject, PosScore: 0.0, NegScore: 0.125
# Word: outside, PosScore: 0.125, NegScore: 0.0
# Word: suffering, PosScore: 0.0, NegScore: 0.375
# Word: condition, PosScore: 0.25, NegScore: 0.0
# Word: outside, PosScore: 0.125, NegScore: 0.0
# Word: suffering, PosScore: 0.0, NegScore: 0.375
# Word: condition, PosScore: 0.25, NegScore: 0.0
# Word: extended, PosScore: 0.375, NegScore: 0.25
# Word: period, PosScore: 0.125, NegScore: 0.0
# Word: region, PosScore: 0.0, NegScore: 0.125
# Word: note, PosScore: 0.0, NegScore: 0.125
# Word: water, PosScore: 0.0, NegScore: 0.125
# Word: supply, PosScore: 0.125, NegScore: 0.0
# Word: region, PosScore: 0.0, NegScore: 0.125
# Word: precipitation, PosScore: 0.25, NegScore: 0.125
# Word: worsened, PosScore: 0.556, NegScore: 0.444
# Word: man, PosScore: 0.125, NegScore: 0.0
# Word: substantial, PosScore: 0.25, NegScore: 0.0
# Word: affected, PosScore: 0.375, NegScore: 0.0
# Word: region, PosScore: 0.0, NegScore: 0.125
# Word: even, PosScore: 0.375, NegScore: 0.0
# Word: short, PosScore: 0.125, NegScore: 0.75
# Word: intense, PosScore: 0.125, NegScore: 0.25
# Word: significant, PosScore: 0.375, NegScore: 0.0
# Word: damage, PosScore: 0.0, NegScore: 0.75
# Word: play, PosScore: 0.125, NegScore: 0.0
# Word: general, PosScore: 0.0, NegScore: 0.125
# Word: change, PosScore: 0.125, NegScore: 0.0
# Word: speculate, PosScore: 0.0, NegScore: 0.125
# Word: substantial, PosScore: 0.25, NegScore: 0.0
# Word: region, PosScore: 0.0, NegScore: 0.125
# Word: normal, PosScore: 0.5, NegScore: 0.125
# Word: mitigation, PosScore: 0.375, NegScore: 0.375
# Word: strategy, PosScore: 0.125, NegScore: 0.0
# Word: place, PosScore: 0.375, NegScore: 0.0
# Word: greatly, PosScore: 0.125, NegScore: 0.0
# Word: reduce, PosScore: 0.0, NegScore: 0.125
# Word: bring, PosScore: 0.0, NegScore: 0.5
# Word: ecological, PosScore: 0.0, NegScore: 0.375
# Word: shortage, PosScore: 0.375, NegScore: 0.375
# Word: still, PosScore: 0.0, NegScore: 0.125
# Word: significant, PosScore: 0.375, NegScore: 0.0
# Word: environmental, PosScore: 0.0, NegScore: 0.125
# Word: economic, PosScore: 0.5, NegScore: 0.0
# Word: social, PosScore: 0.125, NegScore: 0.25
# Word: common, PosScore: 0.222, NegScore: 0.778
# Word: yield, PosScore: 0.0, NegScore: 0.125
# Word: common, PosScore: 0.222, NegScore: 0.778
# Word: time, PosScore: 0.75, NegScore: 0.0
# Word: water, PosScore: 0.0, NegScore: 0.125
# Word: industrial, PosScore: 0.625, NegScore: 0.0
# Word: storm, PosScore: 0.0, NegScore: 0.125
# Word: disease, PosScore: 0.375, NegScore: 0.25
# Word: due, PosScore: 0.375, NegScore: 0.0
# Word: water, PosScore: 0.0, NegScore: 0.125
# Word: unrest, PosScore: 0.125, NegScore: 0.75
# Word: international, PosScore: 0.0, NegScore: 0.5
# Word: natural, PosScore: 0.25, NegScore: 0.125
# Word: water, PosScore: 0.0, NegScore: 0.125
# Word: effect, PosScore: 0.0, NegScore: 0.25
# Word: according, PosScore: 0.125, NegScore: 0.0
# Word: vulnerability, PosScore: 0.125, NegScore: 0.0
# Word: subsistence, PosScore: 0.25, NegScore: 0.25
# Word: likely, PosScore: 0.5, NegScore: 0.0
# Word: alternative, PosScore: 0.0, NegScore: 0.125
# Word: subsistence, PosScore: 0.25, NegScore: 0.25
# Word: major, PosScore: 0.375, NegScore: 0.0
# Word: vulnerable, PosScore: 0.375, NegScore: 0.25
# Word: famine, PosScore: 0.0, NegScore: 0.25
# Word: sole, PosScore: 0.125, NegScore: 0.0
# Word: famine, PosScore: 0.0, NegScore: 0.25
# Word: extreme, PosScore: 0.125, NegScore: 0.0
# Word: poverty, PosScore: 0.0, NegScore: 0.625
# Word: play, PosScore: 0.125, NegScore: 0.0
# Word: major, PosScore: 0.375, NegScore: 0.0
# Word: reduce, PosScore: 0.0, NegScore: 0.125
# Word: water, PosScore: 0.0, NegScore: 0.125
# Word: quality, PosScore: 0.375, NegScore: 0.0
# Word: lower, PosScore: 0.0, NegScore: 0.5
# Word: water, PosScore: 0.0, NegScore: 0.125
# Word: flow, PosScore: 0.0, NegScore: 0.125
# Word: reduce, PosScore: 0.0, NegScore: 0.125
# Word: dilution, PosScore: 0.0, NegScore: 0.25
# Word: water, PosScore: 0.0, NegScore: 0.125
# Word: retreat, PosScore: 0.0, NegScore: 0.125
# Word: retreat, PosScore: 0.0, NegScore: 0.125
# Word: condition, PosScore: 0.25, NegScore: 0.0
# Word: worsen, PosScore: 0.0, NegScore: 0.25
# Word: go, PosScore: 0.375, NegScore: 0.0
# Word: stage, PosScore: 0.25, NegScore: 0.0
# Word: ultimate, PosScore: 0.0, NegScore: 0.125
# Word: period, PosScore: 0.125, NegScore: 0.0
# Word: precipitation, PosScore: 0.25, NegScore: 0.125
# Word: kind, PosScore: 0.625, NegScore: 0.0
# Word: affect, PosScore: 0.125, NegScore: 0.125
# Word: production, PosScore: 0.0, NegScore: 0.125
# Word: range, PosScore: 0.375, NegScore: 0.0
# Word: condition, PosScore: 0.25, NegScore: 0.0
# Word: independently, PosScore: 0.0, NegScore: 0.375
# Word: change, PosScore: 0.125, NegScore: 0.0
# Word: precipitation, PosScore: 0.25, NegScore: 0.125
# Word: level, PosScore: 0.0, NegScore: 0.25
# Word: soil, PosScore: 0.0, NegScore: 0.75
# Word: condition, PosScore: 0.25, NegScore: 0.0
# Word: poorly, PosScore: 0.0, NegScore: 0.75
# Word: water, PosScore: 0.0, NegScore: 0.125
# Word: available, PosScore: 0.375, NegScore: 0.0
# Word: extended, PosScore: 0.375, NegScore: 0.25
# Word: period, PosScore: 0.125, NegScore: 0.0
# Word: precipitation, PosScore: 0.25, NegScore: 0.125
# Word: water, PosScore: 0.0, NegScore: 0.125
# Word: reserve, PosScore: 0.0, NegScore: 0.375
# Word: available, PosScore: 0.375, NegScore: 0.0
# Word: fall, PosScore: 0.125, NegScore: 0.0
# Word: loss, PosScore: 0.0, NegScore: 0.25
# Word: instance, PosScore: 0.375, NegScore: 0.0
# Word: large, PosScore: 0.125, NegScore: 0.0
# Word: water, PosScore: 0.0, NegScore: 0.125
# Word: rule, PosScore: 0.125, NegScore: 0.0
# Word: circumstance, PosScore: 0.25, NegScore: 0.0
# Word: place, PosScore: 0.375, NegScore: 0.0
# Word: risk, PosScore: 0.0, NegScore: 0.25
# Word: completely, PosScore: 0.25, NegScore: 0.0
# Word: mitigation, PosScore: 0.375, NegScore: 0.375
# Word: strategy, PosScore: 0.125, NegScore: 0.0
# Word: sea, PosScore: 0.0, NegScore: 0.125
# Word: water, PosScore: 0.0, NegScore: 0.125
# Word: level, PosScore: 0.0, NegScore: 0.25
# Word: comparison, PosScore: 0.0, NegScore: 0.125
# Word: usage, PosScore: 0.25, NegScore: 0.0
# Word: level, PosScore: 0.0, NegScore: 0.25
# Word: help, PosScore: 0.125, NegScore: 0.0
# Word: prevent, PosScore: 0.25, NegScore: 0.0
# Word: instance, PosScore: 0.375, NegScore: 0.0
# Word: water, PosScore: 0.0, NegScore: 0.125
# Word: usage, PosScore: 0.25, NegScore: 0.0
# Word: water, PosScore: 0.0, NegScore: 0.125
# Word: underground, PosScore: 0.25, NegScore: 0.25
# Word: water, PosScore: 0.0, NegScore: 0.125
# Word: level, PosScore: 0.0, NegScore: 0.25
# Word: put, PosScore: 0.125, NegScore: 0.0
# Word: risk, PosScore: 0.0, NegScore: 0.25
# Word: fertilize, PosScore: 0.125, NegScore: 0.0
# Word: level, PosScore: 0.0, NegScore: 0.25
# Word: help, PosScore: 0.125, NegScore: 0.0
# Word: risk, PosScore: 0.0, NegScore: 0.25
# Word: use, PosScore: 0.25, NegScore: 0.0
# Word: help, PosScore: 0.125, NegScore: 0.0
# Word: minimize, PosScore: 0.0, NegScore: 0.125
# Word: plant, PosScore: 0.125, NegScore: 0.0
# Word: water, PosScore: 0.0, NegScore: 0.125
# Word: treated, PosScore: 0.125, NegScore: 0.25
# Word: canal, PosScore: 0.0, NegScore: 0.625
# Word: restriction, PosScore: 0.25, NegScore: 0.0
# Word: use, PosScore: 0.25, NegScore: 0.0
# Word: involve, PosScore: 0.125, NegScore: 0.0
# Word: use, PosScore: 0.25, NegScore: 0.0
# Word: plant, PosScore: 0.125, NegScore: 0.0
# Word: motor, PosScore: 0.25, NegScore: 0.0
# Word: hard, PosScore: 0.0, NegScore: 0.875
# Word: surface, PosScore: 0.375, NegScore: 0.125
# Word: topping, PosScore: 1.0, NegScore: 0.0
# Word: swimming, PosScore: 0.0, NegScore: 0.375
# Word: pool, PosScore: 0.0, NegScore: 0.25
# Word: fitting, PosScore: 0.5, NegScore: 0.0
# Word: water, PosScore: 0.0, NegScore: 0.125
# Word: inside, PosScore: 0.125, NegScore: 0.125
# Word: home, PosScore: 0.25, NegScore: 0.0
# Word: tap, PosScore: 0.25, NegScore: 0.0
# Word: flush, PosScore: 0.0, NegScore: 0.625
# Word: toilet, PosScore: 0.0, NegScore: 0.5
# Word: selected, PosScore: 0.125, NegScore: 0.0
# Word: minor, PosScore: 0.0, NegScore: 0.25
# Word: check, PosScore: 0.0, NegScore: 0.25
# Word: change, PosScore: 0.125, NegScore: 0.0
# Word: see, PosScore: 0.75, NegScore: 0.0
# Word: detail, PosScore: 0.125, NegScore: 0.0
# Word: available, PosScore: 0.375, NegScore: 0.0
# Sentiment score: 0.007022471910112349

# %%
articles_to_analyze = [
    '1755_Lisbon_earthquake.txt',
    '1896_Summer_Olympics.txt',
    '1997_Pacific_hurricane_season.txt',
    'Actinium.txt',
    'Barracuda.txt',
    'Basketball.txt',
    'Bath_School_disaster.txt',
    'Chicago.txt',
    'Chocolate.txt',
    'Diamond.txt',
    'Dice.txt',
    'Drinking_water.txt',
    'Duchenne_muscular_dystrophy.txt',
    'Geography_of_Ireland.txt',
    'George_S_Richardson_engineer.txt',
    'Giraffe.txt',
    'Gunpowder.txt',
    'Ordinal_number.txt',
    'Osama_bin_Laden.txt',
    'Palm_oil.txt',
    'Peace.txt',
    'Pellagra.txt',
    'Phishing.txt',
    'Plant.txt',
    'Plato.txt',
    'Pneumonia.txt',
    'Poison_gas_in_World_War_I.txt',
    'Politics.txt',
    'Pollution.txt',
    'Pompeii.txt',
    'Recycling.txt',
    'Red_Kite.txt',
    'Rice.txt',
    'Rio_de_Janeiro.txt',
    'Robert_K_Beck.txt',
    'Romeo_and_Juliet.txt',
    'Rugby_World_Cup.txt',
    'Rwandan_Genocide.txt',
    'Salt.txt',
    'Sand.txt',
    'Santa_Claus.txt',
    'Scooby-Doo.txt',
    'Seed.txt',
    'Sequoia.txt'
]

# %%
from transformers import AutoModelForSequenceClassification, AutoTokenizer
import numpy as np
from scipy.special import softmax
import csv
import urllib.request

# Function to preprocess the text
def preprocess(text):
    new_text = []
    for t in text.split(" "):
        t = '@user' if t.startswith('@') and len(t) > 1 else t
        t = 'http' if t.startswith('http') else t
        new_text.append(t)
    return " ".join(new_text)

# Function to chunk text into manageable parts
def chunk_text(text, max_length):
    words = text.split()
    for i in range(0, len(words), max_length):
        yield ' '.join(words[i:i+max_length])

# Function to adjust score with the lexicon
def adjust_score_with_lexicon(text, score, positive_words, negative_words, max_adjustment=0.5):
    words = text.split()
    positive_count = sum(word in positive_words for word in words)
    negative_count = sum(word in negative_words for word in words)

    if abs(score) >= 0.2:
        difference = positive_count - negative_count
        adjustment = (np.log(abs(difference) + 1) / np.log(max_adjustment + 1)) * np.sign(difference)
        adjustment = np.clip(adjustment, -max_adjustment, max_adjustment)
    else:
        return score

    score += adjustment
    score = np.clip(score, -1, 1)
    return score

# %%
import os
import zipfile

zip_file_path = '/content/plaintext_articles.zip'
extract_dir = '/content/extracted_articles'


# Extract the zip file
with zipfile.ZipFile(zip_file_path, 'r') as zip_ref:
    zip_ref.extractall(extract_dir)

# After extracting, get the list of all files in the directory
extracted_files = os.listdir(extract_dir)
print("Extracted files:", extracted_files)
extracted_files = os.listdir(extract_dir +'/' + extracted_files[0])
print("Extracted files:", extracted_files)
# Ensure the files to analyze are in the extracted files list
text_files = [os.path.join(extract_dir +'/plaintext_articles' , file) for file in articles_to_analyze if file in extracted_files]
print(text_files)

for file_path in text_files:
    with open(file_path, 'r') as file:
        text = file.read()

    # Define the task and model
    task = 'sentiment'
    MODEL = f"cardiffnlp/twitter-roberta-base-{task}"

    # Load tokenizer and model from Hugging Face
    tokenizer = AutoTokenizer.from_pretrained(MODEL)
    model = AutoModelForSequenceClassification.from_pretrained(MODEL)

    # Set the max_length for tokenization
    max_length = 512

    # Download and load the label mapping
    labels = []
    mapping_link = f"https://raw.githubusercontent.com/cardiffnlp/tweeteval/main/datasets/{task}/mapping.txt"
    with urllib.request.urlopen(mapping_link) as f:
        html = f.read().decode('utf-8').split("\n")
        csvreader = csv.reader(html, delimiter='\t')
    labels = [row[1] for row in csvreader if len(row) > 1]

    # Load positive and negative words lists (assuming you have them as text files)
    positive_words = set(open('/content/Positive words.txt').read().splitlines())
    negative_words = set(open('/content/Negative words.txt').read().splitlines())

    chunks = chunk_text(preprocess(text), max_length)
    final_scores = np.zeros(len(labels))
    for chunk in chunks:
        encoded_input = tokenizer(chunk, return_tensors='pt', truncation=True, max_length=max_length)
        output = model(**encoded_input)
        scores = softmax(output[0][0].detach().numpy())
        final_scores += scores


    final_scores /= final_scores.sum()

    sentiment_score = final_scores[2] - final_scores[0]  # Positive score minus negative score
    sentiment_score = adjust_score_with_lexicon(preprocess(text), sentiment_score, positive_words, negative_words)

    print(f"File: {os.path.basename(file_path)} - Sentiment score: {sentiment_score:.2f}")
# Out:
# Extracted files: ['plaintext_articles']
# Extracted files: ['Palace_of_Westminster.txt', 'Romulus_Augustus.txt', 'The_Holocaust.txt', 'Wikimedia_Foundation.txt', 'Mickey_Mantle.txt', 'Suriname.txt', 'South_America.txt', 'Foie_gras.txt', 'Spacecraft_propulsion.txt', 'Augustan_literature.txt', 'Cubism.txt', 'Wikipedia_Text_of_the_GNU_Free_Documentation_License.txt', 'Northern_Mariana_Islands.txt', 'Roan_Antelope.txt', 'Trade_union.txt', 'Cologne.txt', 'Isambard_Kingdom_Brunel.txt', '47_Ursae_Majoris_b.txt', 'Gliese_876_b.txt', 'Tiktaalik.txt', 'Rubik%27s_Cube.txt', 'Invasion.txt', 'Cape_Lion.txt', 'Economy_of_Africa.txt', 'England.txt', 'Mark_Antony.txt', 'Italian_War_of_1521.txt', 'Spider.txt', 'Dada.txt', 'Ipswich.txt', 'Lisbon.txt', 'Stephen_of_England.txt', 'Ghost_Dance.txt', 'Comoros.txt', 'Crab_Nebula.txt', 'Zinc.txt', 'Santorini.txt', 'United_States.txt', 'Strait_of_Malacca.txt', 'Hugo_Wolf.txt', 'Lovage.txt', 'Goleta%2C_California.txt', 'James_I_of_England.txt', 'Okapi.txt', 'Medieval_literature.txt', 'Tree.txt', 'Leo_Tolstoy.txt', '17th_century.txt', 'Mount_Vesuvius.txt', 'James_Lovelock.txt', 'Henry_II_of_England.txt', 'Fidel_Castro.txt', 'Sim%C3%B3n_Bol%C3%ADvar.txt', 'Jan_Mayen.txt', 'Planetary_nebula.txt', 'S%C3%A3o_Tom%C3%A9_and_Pr%C3%ADncipe.txt', 'Vanuatu.txt', 'Edward_III_of_England.txt', 'Barium.txt', 'Pollinator.txt', 'Roald_Amundsen.txt', 'Bat.txt', 'Fatty_acid.txt', 'Fiction.txt', 'Concorde.txt', 'Consolation_of_Philosophy.txt', 'StarCraft.txt', 'Abraham_Lincoln.txt', 'Senegal.txt', '1980_eruption_of_Mount_St._Helens.txt', 'Peter_Paul_Rubens.txt', 'Olaudah_Equiano.txt', 'The_King%27s_Regiment_%28Liverpool%29.txt', 'Lebanon.txt', 'Hrafnkels_saga.txt', 'Boston_RFC.txt', 'Wernher_von_Braun.txt', 'Behistun_Inscription.txt', 'Triumph_of_the_Will.txt', 'Indian_Railways.txt', 'James_Bond.txt', 'Euclidean_geometry.txt', 'Gossypium.txt', 'Train.txt', 'List_of_particles.txt', 'Tupac_Shakur.txt', 'Starling.txt', 'PRR_GG1.txt', 'Cosmic_microwave_background_radiation.txt', 'Jackdaw.txt', 'Odyssey.txt', 'Walt_Whitman.txt', 'Mammoth_Cave_National_Park.txt', 'H.D..txt', 'American_Samoa.txt', 'J._S._Fry_%26_Sons.txt', 'Jaws_%28film%29.txt', 'Los_Angeles%2C_California.txt', 'Buddha.txt', 'Lemon.txt', 'African_dwarf_frog.txt', 'White_Mountain_art.txt', 'Madrid.txt', 'Corrosion.txt', 'Suez_Canal.txt', 'Haiti.txt', 'Honey_bee.txt', 'Diamond_simulant.txt', 'Indonesian_language.txt', 'Nashville%2C_Tennessee.txt', 'Sorghum.txt', 'Electricity.txt', 'Local_community.txt', 'Victoria%2C_Seychelles.txt', 'History_of_Buddhism.txt', 'Differential_geometry_and_topology.txt', 'Serbia_and_Montenegro.txt', 'Lake_Tanganyika.txt', 'The_Ashes.txt', 'Thermodynamic_temperature.txt', 'History_of_the_Australian_Capital_Territory.txt', 'Chicago.txt', 'Dice.txt', 'Star_Trek.txt', 'Hatshepsut.txt', 'Qin_Shi_Huang.txt', 'Olive_oil.txt', 'Greg_LeMond.txt', 'List_of_animal_welfare_groups.txt', 'Watchmen.txt', 'Avro_Lancaster.txt', 'Attack_on_Pearl_Harbor.txt', 'San_Diego_Electric_Railway.txt', 'Imperative_programming.txt', 'Roman_Empire.txt', 'Seaborgium.txt', 'Pied_Avocet.txt', 'Chestnut.txt', 'The_Great_Exhibition.txt', 'Thiamine.txt', 'Pope_Benedict_XVI.txt', 'Oasis_%28band%29.txt', 'Jazz.txt', 'River_Severn.txt', 'Programming_language.txt', 'Phishing.txt', 'Hebrides.txt', 'Cape_Horn.txt', 'Asparagus.txt', 'Comet.txt', 'Vulgar_Latin.txt', 'William_Harvey.txt', 'Mount_Rainier.txt', 'Pericles.txt', 'History_of_the_world.txt', 'Copenhagen.txt', 'Energy.txt', 'Robert_Stephenson.txt', 'Punctuated_equilibrium.txt', 'Boa.txt', 'Bohemian_Rhapsody.txt', 'Doha.txt', 'Rutherford_B._Hayes.txt', 'Nutmeg.txt', 'Bologna.txt', 'African_Union.txt', 'Lead%28II%29_nitrate.txt', 'Juice.txt', 'Zirconium.txt', 'U.S._state.txt', 'Bicycle_Thieves.txt', 'Goa.txt', 'Boyle_Roche.txt', 'Piano.txt', 'Fresh_water.txt', 'Earwax.txt', 'Chordate.txt', 'Achilles.txt', 'LANSA_Cuzco_Crash.txt', 'Tennis.txt', 'Second_Boer_War.txt', 'General_Pershing_Zephyr.txt', 'Battle_of_Amiens.txt', 'Slovenia.txt', 'Philosophy.txt', 'Fruit.txt ...
# ['/content/extracted_articles/plaintext_articles/1755_Lisbon_earthquake.txt', '/content/extracted_articles/plaintext_articles/1896_Summer_Olympics.txt', '/content/extracted_articles/plaintext_articles/1997_Pacific_hurricane_season.txt', '/content/extracted_articles/plaintext_articles/Actinium.txt', '/content/extracted_articles/plaintext_articles/Barracuda.txt', '/content/extracted_articles/plaintext_articles/Basketball.txt', '/content/extracted_articles/plaintext_articles/Bath_School_disaster.txt', '/content/extracted_articles/plaintext_articles/Chicago.txt', '/content/extracted_articles/plaintext_articles/Chocolate.txt', '/content/extracted_articles/plaintext_articles/Diamond.txt', '/content/extracted_articles/plaintext_articles/Dice.txt', '/content/extracted_articles/plaintext_articles/Drinking_water.txt', '/content/extracted_articles/plaintext_articles/Duchenne_muscular_dystrophy.txt', '/content/extracted_articles/plaintext_articles/Geography_of_Ireland.txt', '/content/extracted_articles/plaintext_articles/Giraffe.txt', '/content/extracted_articles/plaintext_articles/Gunpowder.txt', '/content/extracted_articles/plaintext_articles/Ordinal_number.txt', '/content/extracted_articles/plaintext_articles/Osama_bin_Laden.txt', '/content/extracted_articles/plaintext_articles/Palm_oil.txt', '/content/extracted_articles/plaintext_articles/Peace.txt', '/content/extracted_articles/plaintext_articles/Pellagra.txt', '/content/extracted_articles/plaintext_articles/Phishing.txt', '/content/extracted_articles/plaintext_articles/Plant.txt', '/content/extracted_articles/plaintext_articles/Plato.txt', '/content/extracted_articles/plaintext_articles/Pneumonia.txt', '/content/extracted_articles/plaintext_articles/Poison_gas_in_World_War_I.txt', '/content/extracted_articles/plaintext_articles/Politics.txt', '/content/extracted_articles/plaintext_articles/Pollution.txt', '/content/extracted_articles/plaintext_articles/Pompeii.txt', '/content/extracted_articles/plaintext_articles/Recycling.txt', '/content/extracted_articles/plaintext_articles/Red_Kite.txt', '/content/extracted_articles/plaintext_articles/Rice.txt', '/content/extracted_articles/plaintext_articles/Rio_de_Janeiro.txt', '/content/extracted_articles/plaintext_articles/Romeo_and_Juliet.txt', '/content/extracted_articles/plaintext_articles/Rugby_World_Cup.txt', '/content/extracted_articles/plaintext_articles/Rwandan_Genocide.txt', '/content/extracted_articles/plaintext_articles/Salt.txt', '/content/extracted_articles/plaintext_articles/Sand.txt', '/content/extracted_articles/plaintext_articles/Santa_Claus.txt', '/content/extracted_articles/plaintext_articles/Scooby-Doo.txt', '/content/extracted_articles/plaintext_articles/Seed.txt', '/content/extracted_articles/plaintext_articles/Sequoia.txt']
# File: 1755_Lisbon_earthquake.txt - Sentiment score: -0.75
# File: 1896_Summer_Olympics.txt - Sentiment score: 0.12
# File: 1997_Pacific_hurricane_season.txt - Sentiment score: -0.71
# File: Actinium.txt - Sentiment score: -0.85
# File: Barracuda.txt - Sentiment score: -0.08
# File: Basketball.txt - Sentiment score: 0.06
# File: Bath_School_disaster.txt - Sentiment score: -0.81
# File: Chicago.txt - Sentiment score: 0.15
# File: Chocolate.txt - Sentiment score: -0.08
# File: Diamond.txt - Sentiment score: 0.08
# File: Dice.txt - Sentiment score: -0.07
# File: Drinking_water.txt - Sentiment score: 0.21
# File: Duchenne_muscular_dystrophy.txt - Sentiment score: -0.12
# File: Geography_of_Ireland.txt - Sentiment score: 0.06
# File: Giraffe.txt - Sentiment score: -0.14
# File: Gunpowder.txt - Sentiment score: -0.14
# File: Ordinal_number.txt - Sentiment score: 0.04
# File: Osama_bin_Laden.txt - Sentiment score: -0.80
# File: Palm_oil.txt - Sentiment score: 0.08
# File: Peace.txt - Sentiment score: 0.03
# File: Pellagra.txt - Sentiment score: -0.86
# File: Phishing.txt - Sentiment score: -1.00
# File: Plant.txt - Sentiment score: -0.07
# File: Plato.txt - Sentiment score: -0.07
# File: Pneumonia.txt - Sentiment score: -0.93
# File: Poison_gas_in_World_War_I.txt - Sentiment score: -0.94
# File: Politics.txt - Sentiment score: -0.11
# File: Pollution.txt - Sentiment score: -0.82
# File: Pompeii.txt - Sentiment score: -0.06
# File: Recycling.txt - Sentiment score: -0.14
# File: Red_Kite.txt - Sentiment score: -0.05
# File: Rice.txt - Sentiment score: -0.01
# File: Rio_de_Janeiro.txt - Sentiment score: 0.86
# File: Romeo_and_Juliet.txt - Sentiment score: -0.03
# File: Rugby_World_Cup.txt - Sentiment score: 0.15
# File: Rwandan_Genocide.txt - Sentiment score: -0.96
# File: Salt.txt - Sentiment score: 0.29
# File: Sand.txt - Sentiment score: 0.07
# File: Santa_Claus.txt - Sentiment score: 0.11
# File: Scooby-Doo.txt - Sentiment score: 0.08
# File: Seed.txt - Sentiment score: -0.16
# File: Sequoia.txt - Sentiment score: 0.14

# %% [markdown]
# # 5.

# %%
file_names = ['1755_Lisbon_earthquake','1896_Summer_Olympics','1997_Pacific_hurricane_season','Actinium','Barracuda','Basketball','Bath_School_disaster','Chicago','Chocolate','Diamond','Dice','Drinking_water','Duchenne_muscular_dystrophy','Geography_of_Ireland','Giraffe','Gunpowder','Osama_bin_Laden','Palm_oil','Peace','Pellagra','Phishing','Plant','Plato','Pneumonia','Poison_gas_in_World_War_I','Politics','Pollution','Red_Kite','Rice','Rio_de_Janeiro','Romeo_and_Juliet','Rugby_World_Cup','Rwandan_Genocide','Santa_Claus','Scooby-Doo']
len(file_names)
# Out:
# 35

# %% [markdown]
# ### MODEL DESCRIPTION
# Pattern is a multipurpose library that is capable of handling NLP operations, data mining, machine learning etc. It also contains sentiment analysis functionality which is suitable for our task.
# The `sentiment` function under `pattern.text.en` module is used to calculate the sentiment of a given text, it takes a sentence as input which can also be a string, Synset, word or document, and returns a (polarity, subjectivity)-tuple with polarity between -1.0 and +1.0 and subjectivity between 0.0 and 1.0. polarity describes the emotional leaning of the text, while subjectivity describes the strength of such emotion.
#
# In our usage the input is a string of the entire article loaded from the Wikispeedia dataset, In this case, it first tokenizes the text into words(punctuation, space and abbreviations are handled at this stage), then it Lowercases each word because sentiment analysis is case insensitive. Next it calculates the sentiment of each word by consulting the predefined sentiment [dictionary](https://github.com/clips/pattern/blob/master/pattern/text/en/en-sentiment.xml)(modifiers and negations are also considered at this time). Finally it returns the average of all the words as the sentiment of the text.
#
# Pattern is a classic and well-known non-commercial library for the sentiment analysis task solution, the module itself lasts over 10 years and has 8.6k stars on github. It provides detailed results (polarity and subjectivity) for many mainstream languages, and its API is fast and easy to use with other NLP preprocessing tools embedded. More details can be found in the [official documentation](https://digiasset.org/html/pattern.html) and [repository](https://digiasset.org/html/pattern.html).

# %% [markdown]
# ### METHOD && RESULTS
# Each selected article is loaded and feeded into the `sentiment` function, the polarity is then printed out. The results are shown below.

# %%
from pattern.text.en import sentiment

for file_name in file_names:
    with open('data/plaintext_articles/'+file_name+'.txt', 'r', encoding='utf-8') as file:
        data = file.read()
        polarity, subjectivity = sentiment(data)
        print(f"{file_name}: {polarity}")
# Out:
# 1755_Lisbon_earthquake: 0.0816923282902664
# 1896_Summer_Olympics: 0.11173071331653418
# 1997_Pacific_hurricane_season: 0.051366249491249474
# Actinium: 0.03542682926829269
# Barracuda: 0.1132213321465658
# Basketball: 0.08600218021995364
# Bath_School_disaster: 0.010679336219336222
# Chicago: 0.10564842500695483
# Chocolate: 0.07674311830989919
# Diamond: 0.12359236785162714
# Dice: -0.0001423413188119043
# Drinking_water: 0.12155415214866433
# Duchenne_muscular_dystrophy: 0.051342562953478464
# Geography_of_Ireland: 0.06101678376268537
# Giraffe: 0.04892030793508625
# Gunpowder: 0.01667841269841271
# Osama_bin_Laden: 0.04482218734525007
# Palm_oil: 0.10377811870669014
# Peace: 0.07109719189365207
# Pellagra: 0.013132859204287773
# Phishing: 0.03130031080031078
# Plant: 0.09383068133068131
# Plato: 0.16051446416831025
# Pneumonia: 0.05341062158293232
# Poison_gas_in_World_War_I: 0.08464027042373903
# Politics: 0.10395405509821987
# Pollution: 0.08715013543960917
# Red_Kite: 0.035212025919573085
# Rice: 0.08478642004761416
# Rio_de_Janeiro: 0.15940676171654442
# Romeo_and_Juliet: 0.08846829977782353
# Rugby_World_Cup: 0.09477842945584883
# Rwandan_Genocide: 0.05457812020169003
# Santa_Claus: 0.08992885441238731
# Scooby-Doo: 0.1352173090752449

# %% [markdown]
# The MSE is compared with the human labeled result(trinary value among -1 0 1) which is around **0.7**

# %% [markdown]
# ### DISCUSSION
# The performance of this model is generally not good compared to other models we tested, the possible reason could be that it uses a fixed sentiment dictionary which may contain bias between different domains. It's observed that the model tends to give a very small value between [0,0.1] despite the articles, a reason could be that Wikipedia articles are designed to be neutral and objective, It generally looks at problems dialectically and rarely produces strong emotions. However, in the range of this project, we care more about the sentiment level of the article (the word itself) rather than the way it is written, the model considers all the words on the page evenly and thus may produce results that are not what we expect.
#
# This is not the optimal model for our task, a ML-based approach is generally more flexible and powerful in this case.
